# %% [markdown]
# <a href="https://colab.research.google.com/github/RogerNauer/DSToolbox/blob/master/Activity3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path1_anth='/content/drive/MyDrive/Colab Notebooks/antropometria-dataset-2.csv'
path2_adul='/content/drive/MyDrive/Colab Notebooks/adult.csv'

# %%
df1=pd.read_csv(path1_anth)
df1.head()
# Out:
#     folio  intp  entidad          desc_ent  sexo  edad  meses   peso  ropa  \
# 0  210295     2       21            PUEBLA     2    38      8  73.70     2
# 1  101655     3       10           DURANGO     2    11     11  35.65     2
# 2   10287     6        1    AGUASCALIENTES     2    18      8  54.80     1
# 3   91526     4        9  DISTRITO FEDERAL     1    10      8  33.40     2
# 4  210939     3       21            PUEBLA     2    19      3  97.95     2
#
#    talla  ... hpresion tbrazo  htension  PrimaryLast  code_upm  est_dis  \
# 0  146.4  ...    16:30      2     16:35            1     R2101        5
# 1  145.1  ...    15:25      3     15:25            1     M1041        1
# 2  162.0  ...     9:40      1      9:40            1     M0108        5
# 3  146.5  ...     7:40      3      7:45            1     M0931        4
# 4  161.0  ...     6:00      2      6:00            1     M2123        5
#
#   est_urb est_marg       pondef  est_var
# ...

# %%
df1.isnull().any()
# Out:
# folio          False
# intp           False
# entidad        False
# desc_ent       False
# sexo           False
# edad           False
# meses          False
# peso           False
# ropa           False
# talla          False
# emb            False
# temb           False
# cintura         True
# cadera          True
# sistol         False
# diastol        False
# hpresion       False
# tbrazo         False
# htension       False
# PrimaryLast    False
# code_upm       False
# est_dis        False
# est_urb        False
# est_marg       False
# pondef         False
# est_var        False
# dtype: bool

# %%
df1.isna().any()
# Out:
# folio          False
# intp           False
# entidad        False
# desc_ent       False
# sexo           False
# edad           False
# meses          False
# peso           False
# ropa           False
# talla          False
# emb            False
# temb           False
# cintura         True
# cadera          True
# sistol         False
# diastol        False
# hpresion       False
# tbrazo         False
# htension       False
# PrimaryLast    False
# code_upm       False
# est_dis        False
# est_urb        False
# est_marg       False
# pondef         False
# est_var        False
# dtype: bool

# %%
pd.pivot_table(df1,index='desc_ent',values='peso', aggfunc='mean', margins=True).sort_values(by=['peso'],ascending=False)
# Out:
#                                       peso
# desc_ent
# BAJA CALIFORNIA SUR              71.809198
# SONORA                           68.849473
# COLIMA                           68.743648
# BAJA CALIFORNIA                  68.467270
# TAMAULIPAS                       68.210911
# COAHUILA DE ZARAGOZA             68.154142
# SINALOA                          68.051272
# NUEVO LEON                       67.239853
# JALISCO                          66.697270
# CHIHUAHUA                        66.656005
# TABASCO                          66.554701
# NAYARIT                          66.541827
# AGUASCALIENTES                   66.357786
# DURANGO                          66.354922
# CAMPECHE                         65.418475
# DISTRITO FEDERAL                 65.119273
# MICHOACAN DE OCAMPO              64.900000
# All                              64.638707
# QUINTANA ROO                     64.238904
# ZACATECAS                        64.238524
# ...

# %%
pd.pivot_table(df1,index='desc_ent',values='peso', aggfunc='mean', margins=True, columns='sexo').sort_values(by=[2],ascending=False)
# Out:
# sexo                                     1          2        All
# desc_ent
# BAJA CALIFORNIA SUR              75.561015  68.168959  71.809198
# COAHUILA DE ZARAGOZA             68.873094  67.467348  68.154142
# SONORA                           70.880406  67.024857  68.849473
# COLIMA                           70.998878  66.978393  68.743648
# JALISCO                          67.076482  66.418111  66.697270
# BAJA CALIFORNIA                  71.391818  65.893667  68.467270
# SINALOA                          71.122911  65.565234  68.051272
# NAYARIT                          68.822143  64.890564  66.541827
# TAMAULIPAS                       72.060601  64.866851  68.210911
# NUEVO LEON                       70.168106  64.823014  67.239853
# CHIHUAHUA                        68.892642  64.815295  66.656005
# DURANGO                          68.846451  64.400031  66.354922
# TABASCO                          69.255801  64.190187  66.554701
# ...

# %%
pd.pivot_table(df1,index='desc_ent',values='peso', aggfunc='mean', margins=True, columns='sexo').sort_values(by=[2],ascending=False)
# Out:
# sexo                                     1          2        All
# desc_ent
# BAJA CALIFORNIA SUR              75.561015  68.168959  71.809198
# COAHUILA DE ZARAGOZA             68.873094  67.467348  68.154142
# SONORA                           70.880406  67.024857  68.849473
# COLIMA                           70.998878  66.978393  68.743648
# JALISCO                          67.076482  66.418111  66.697270
# BAJA CALIFORNIA                  71.391818  65.893667  68.467270
# SINALOA                          71.122911  65.565234  68.051272
# NAYARIT                          68.822143  64.890564  66.541827
# TAMAULIPAS                       72.060601  64.866851  68.210911
# NUEVO LEON                       70.168106  64.823014  67.239853
# CHIHUAHUA                        68.892642  64.815295  66.656005
# DURANGO                          68.846451  64.400031  66.354922
# TABASCO                          69.255801  64.190187  66.554701
# ...

# %%
df2=pd.read_csv(path2_adul)
df2.head()
# Out:
#    age          workclass  fnlwgt   education  education-num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital-status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital-gain  capital-loss  hours-per-week  native-country the label
# ...

# %%
type(pd.pivot_table(df2,index='marital-status',values='age', aggfunc='count', margins=True))
# Out:
# pandas.core.frame.DataFrame

# %%
df2['Conteo Casos']=1

# %%
df2
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 32559   22            Private  201490     HS-grad              9
# 32560   52       Self-emp-inc  287927     HS-grad              9
# 32561   52       Self-emp-inc  287927     HS-grad              9
# 32562   52       Self-emp-inc  287927     HS-grad              9
# 32563   52       Self-emp-inc  287927     HS-grad              9
#
#               marital-status          occupation    relationship    race  \
# 0              Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
TablaPivote=pd.pivot_table(df2,index='marital-status',values='Conteo Casos', aggfunc='count', margins=True).rename(columns={'age': 'Conteo Casos'})

# %%
TablaPivote2=pd.pivot_table(df2,index='marital-status',values='Conteo Casos', aggfunc='sum', margins=True)

# %%
TablaPivote2=pd.pivot_table(df2,index=['marital-status','education'],values='hours-per-week', aggfunc='mean', margins=True)

# %%
TablaPivote2
# Out:
#                                      hours-per-week
# marital-status        education
#  Divorced              10th               40.808333
#                        11th               40.023077
#                        12th               39.692308
#                        1st-4th            32.800000
#                        5th-6th            38.900000
# ...                                             ...
#  Widowed               Prof-school        33.200000
#                        Some-college       32.645349
#  test_category_female  HS-grad            40.000000
#  test_category_male    HS-grad            40.000000
# All                                       40.437416
#
# [104 rows x 1 columns]

# %%
TablaPivote2['%Mix']=100

# %%
TablaPivote2['%Mix']=2*TablaPivote2['Conteo Casos']/TablaPivote2['Conteo Casos'].sum()*100

# %%
TablaPivote2
# Out:
#                         Conteo Casos        %Mix
# marital-status
#  Divorced                       4443   13.643901
#  Married-AF-spouse                23    0.070630
#  Married-civ-spouse            14976   45.989436
#  Married-spouse-absent           418    1.283626
#  Never-married                 10683   32.806166
#  Separated                      1025    3.147648
#  Widowed                         993    3.049380
#  test_category_female              1    0.003071
#  test_category_male                2    0.006142
# All                            32564  100.000000

# %%
TablaPivote.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries,  Divorced to All
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Conteo Casos  10 non-null     int64
#  1   %Mix          10 non-null     float64
# dtypes: float64(1), int64(1)
# memory usage: 240.0+ bytes

# %%
df2['marital statusX']=df2['marital-status']

# %%
df2
# Out:
#        age          workclass  fnlwgt   education  education-num  \
# 0       39          State-gov   77516   Bachelors             13
# 1       50   Self-emp-not-inc   83311   Bachelors             13
# 2       38            Private  215646     HS-grad              9
# 3       53            Private  234721        11th              7
# 4       28            Private  338409   Bachelors             13
# ...    ...                ...     ...         ...            ...
# 32559   22            Private  201490     HS-grad              9
# 32560   52       Self-emp-inc  287927     HS-grad              9
# 32561   52       Self-emp-inc  287927     HS-grad              9
# 32562   52       Self-emp-inc  287927     HS-grad              9
# 32563   52       Self-emp-inc  287927     HS-grad              9
#
#               marital-status          occupation    relationship    race  \
# 0              Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
df2.loc[df2["marital statusx"] == "Married-AF-spouse" , "marital statusx"] = 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'marital statusx'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
df2.loc[df2["marital statusx"] == "Married-AF-spouse" OR df2["marital statusx"] == "Married-civ-spouse" OR df2["marital statusx"] == "Married-spouse-absent" , "marital statusx"] = 1

# %%
df2["marital statusx"] = np.where(df2["marital statusx"] == "Married-AF-spouse", "married", df2["marital statusx"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'marital statusx'
#
# The above exception was the direct cause of the following exception:
#
# ...
